# %% [markdown]
# <a href="https://githubtocolab.com/gee-community/geemap/blob/master/docs/notebooks/23_import_assets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %%
import os
import ee
import geemap

# %%
Map = geemap.Map()
Map

# %%
out_dir = os.path.join(os.path.expanduser("~"), "Downloads")
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

# %%
out_csv = os.path.join(out_dir, "ee_api.csv")
geemap.ee_api_to_csv(out_csv)

# %%
geemap.ee_search()
