# %% [markdown]
# <a href="https://githubtocolab.com/gee-community/geemap/blob/master/docs/notebooks/97_join_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %%
import ee
import geemap

# %% [markdown]
# Add data to the map.

# %%
Map = geemap.Map()
countries = ee.FeatureCollection("users/giswqs/public/countries")
Map.addLayer(countries, {}, "Countries")
Map

# %% [markdown]
# Display the attribute table.

# %%
geemap.ee_to_df(countries)

# %% [markdown]
# Get data to be joined to the attribute table.

# %%
data = "https://raw.githubusercontent.com/gee-community/geemap/master/examples/data/countries.geojson"

# %% [markdown]
# Join data to the attribute table.

# %%
fc = geemap.ee_join_table(countries, data, src_key="id", dst_key="ISO_A3")

# %% [markdown]
# Display the new attribute table.

# %%
geemap.ee_to_df(fc)

# %% [markdown]
# Add the new data to the map.

# %%
Map.addLayer(fc, {}, "Countries New")
