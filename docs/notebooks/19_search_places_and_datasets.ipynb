# %% [markdown]
# <a href="https://githubtocolab.com/gee-community/geemap/blob/master/docs/notebooks/19_search_places_and_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %%
import ee
import geemap

# %%
geemap.show_youtube("lwtgzrHrXj8")

# %% [markdown]
# ## Update the geemap package
#
# If you run into errors with this notebook, please uncomment the line below to update the [geemap](https://github.com/gee-community/geemap#installation) package to the latest version from GitHub.
# Restart the Kernel (Menu -> Kernel -> Restart) to take effect.

# %%
# geemap.update_package()

# %% [markdown]
# ## Create an interactive map

# %%
Map = geemap.Map()
Map

# %% [markdown]
# ## Convert marker to ee.Geometry

# %%
Map.search_locations

# %%
Map.search_loc_geom

# %%
location = Map.search_loc_geom
# print(location.getInfo())
