# %% [markdown]
# <a href="https://githubtocolab.com/gee-community/geemap/blob/master/examples/notebooks/109_coordinate_grids.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
# !pip install geemap

# %% [markdown]
# Import libraries.

# %%
import ee
import geemap

# %%
Map = geemap.Map()

# %% [markdown]
# Create a latitude grid.

# %%
lat_grid = geemap.latitude_grid(step=5.0, west=-180, east=180, south=-85, north=85)

# %%
Map.addLayer(lat_grid, {}, "Latitude Grid")

# %%
Map

# %% [markdown]
# Convert `ee.FeatureCollection` to `pandas.DataFrame`.

# %%
df = geemap.ee_to_df(lat_grid)
df

# %% [markdown]
# Create a longitude grid.

# %%
lon_grid = geemap.longitude_grid(step=5.0, west=-180, east=180, south=-85, north=85)

# %%
Map = geemap.Map()
Map.addLayer(lon_grid, {}, "Longitude Grid")
Map

# %% [markdown]
# Create a rectangular grid.

# %%
grid = geemap.latlon_grid(
    lat_step=10, lon_step=10, west=-180, east=180, south=-85, north=85
)

# %%
Map = geemap.Map()
Map.addLayer(grid, {}, "Coordinate Grid")
Map

# %% [markdown]
# ![](https://i.imgur.com/FvRe3Lu.png)
